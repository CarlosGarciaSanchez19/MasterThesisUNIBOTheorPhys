# %%
# %run DecWidthFunc.ipynb

# %%
DATA = np.array(pd.read_excel('DATA GammaV.xlsx'))
ctVData = np.zeros(len(DATA))
mVData = np.zeros(len(DATA))
for i in range(len(DATA)):
    mVData[i] = DATA[i][0]
    ctVData[i] = DATA[i][1]
eps = 1e-2
m_V1 = np.linspace(1e-3, mVData[0], N)
GammaV1 = GammaTot(m_V1, eps, PMS)/eps**2
m_V2 = np.linspace(mVData[-1], 1e3, N)
GammaV2 = GammaTot(m_V2, eps, PMS)/eps**2

GammaVDataeps = np.append(GammaV1, GammaVp)
GammaVDataeps = np.append(GammaVDataeps, GammaV2)
CtVDATAeps = 1/GammaVDataeps
m_VFinal = np.append(m_V1, mVData)
m_VFinal = np.append(m_VFinal, m_V2)

def eps(ctau,GammaVDataeps):
    return 1/np.sqrt(ctau*GammaVDataeps)

# %%
DATA = np.array(pd.read_excel('2107.04838 CMS BSM LLP to dd 7 GeV exclusion -1 points.xlsx'))
CMSdd7GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CMSdd7GeV1[i] = DATA[i][0]
DATA = np.array(pd.read_excel('2107.04838 CMS BSM LLP to dd 7 GeV exclusion -2 points.xlsx'))
CMSdd7GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CMSdd7GeV2[i] = DATA[i][0]
DATA = np.array(pd.read_excel('2107.04838 CMS BSM LLP to dd 55 GeV exclusion -1 points.xlsx'))
CMSdd55GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CMSdd55GeV1[i] = DATA[i][0]
DATA = np.array(pd.read_excel('2107.04838 CMS BSM LLP to dd 55 GeV exclusion -2 points.xlsx'))
CMSdd55GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CMSdd55GeV2[i] = DATA[i][0]
DATA = np.array(pd.read_excel('2107.04838 CMS BSM LLP to tautau 7 GeV exclusion -1 points.xlsx'))
CMStautau7GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CMStautau7GeV1[i] = DATA[i][0]
DATA = np.array(pd.read_excel('2107.04838 CMS BSM LLP to tautau 7 GeV exclusion -2 points.xlsx'))
CMStautau7GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CMStautau7GeV2[i] = DATA[i][0]
DATA = np.array(pd.read_excel('2107.04838 CMS BSM LLP to tautau 55 GeV exclusion -1 points.xlsx'))
CMStautau55GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CMStautau55GeV1[i] = DATA[i][0]
DATA = np.array(pd.read_excel('2107.04838 CMS BSM LLP to tautau 55 GeV exclusion -2 points.xlsx'))
CMStautau55GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CMStautau55GeV2[i] = DATA[i][0]
    
PointsCMSdd1BR = [CMSdd7GeV1, CMSdd55GeV1]
PointsCMSdd2BR = [CMSdd7GeV2, CMSdd55GeV2]
PointsCMStautau1BR = [CMStautau7GeV1, CMStautau55GeV1]
PointsCMStautau2BR = [CMStautau7GeV2, CMStautau55GeV2]

m_VCMSexclu = m_VFinal[(m_VFinal > 7) & (m_VFinal < 55)]

#FOR BR equal 0.1:

ctauInterp = np.interp(m_VCMSexclu, [7,55], [PointsCMSdd1BR[0][0],PointsCMSdd1BR[1][0]])

CMSddepsUpperLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 7) & (m_VFinal < 55)])

ctauInterp = np.interp(m_VCMSexclu, [7,55], [PointsCMSdd1BR[0][1],PointsCMSdd1BR[1][1]])

CMSddepsDownLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 7) & (m_VFinal < 55)])

#FOR BR equal 0.01:

ctauInterp = np.interp(m_VCMSexclu, [7,55], [PointsCMSdd2BR[0][0],PointsCMSdd2BR[1][0]])

CMSddepsUpperLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 7) & (m_VFinal < 55)])

ctauInterp = np.interp(m_VCMSexclu, [7,55], [PointsCMSdd2BR[0][1],PointsCMSdd2BR[1][1]])

CMSddepsDownLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 7) & (m_VFinal < 55)])

#FOR BR equal 0.1:

ctauInterp = np.interp(m_VCMSexclu, [7,55], [PointsCMStautau1BR[0][0],PointsCMStautau1BR[1][0]])

CMStautauepsUpperLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 7) & (m_VFinal < 55)])

ctauInterp = np.interp(m_VCMSexclu, [7,55], [PointsCMStautau1BR[0][1],PointsCMStautau1BR[1][1]])

CMStautauepsDownLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 7) & (m_VFinal < 55)])

#FOR BR equal 0.01:

ctauInterp = np.interp(m_VCMSexclu, [7,55], [PointsCMStautau2BR[0][0],PointsCMStautau2BR[1][0]])

CMStautauepsUpperLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 7) & (m_VFinal < 55)])

ctauInterp = np.interp(m_VCMSexclu, [7,55], [PointsCMStautau2BR[0][1],PointsCMStautau2BR[1][1]])

CMStautauepsDownLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 7) & (m_VFinal < 55)])

# %store CMSddepsUpperLim1
# %store CMSddepsDownLim1
# %store CMSddepsUpperLim2
# %store CMSddepsDownLim2

# %store CMStautauepsUpperLim1
# %store CMStautauepsDownLim1
# %store CMStautauepsUpperLim2
# %store CMStautauepsDownLim2
