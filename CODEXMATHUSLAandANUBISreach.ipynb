# %%
# %run DecWidthFunc.ipynb

# %%
DATA = np.array(pd.read_excel('2203.07316 CODEX-b 10 GeV -1 points.xlsx'))
CODEX10GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CODEX10GeV1[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('2203.07316 CODEX-b 10 GeV -2 points.xlsx'))
CODEX10GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CODEX10GeV2[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('2203.07316 CODEX-b 10 GeV -3 points.xlsx'))
CODEX10GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CODEX10GeV3[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('2203.07316 CODEX-b 0.5 GeV -1 points.xlsx'))
CODEX05GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CODEX05GeV1[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('2203.07316 CODEX-b 0.5 GeV -2 points.xlsx'))
CODEX05GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CODEX05GeV2[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('2203.07316 CODEX-b 0.5 GeV -3 points.xlsx'))
CODEX05GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    CODEX05GeV3[i] = DATA[i][0]

PointsCODEX1BR = [CODEX05GeV1, CODEX10GeV1]
PointsCODEX2BR = [CODEX05GeV2, CODEX10GeV2]
PointsCODEX3BR = [CODEX05GeV3, CODEX10GeV3]

#Now we obtain the particle's lifetime in meters using the data obtained from figure 2 of 1412.0018 
#and accurate functions for lower and greater values of the dark photon mass.

DATA = np.array(pd.read_excel('DATA GammaV.xlsx'))
ctVData = np.zeros(len(DATA))
mVData = np.zeros(len(DATA))
for i in range(len(DATA)):
    mVData[i] = DATA[i][0]
    ctVData[i] = DATA[i][1]
eps = 1e-2
m_V1 = np.linspace(1e-3, mVData[0], N)
GammaV1 = GammaTot(m_V1, eps, PMS)/eps**2
m_V2 = np.linspace(mVData[-1], 1e3, N)
GammaV2 = GammaTot(m_V2, eps, PMS)/eps**2

GammaVDataeps = np.append(GammaV1, GammaVp)
GammaVDataeps = np.append(GammaVDataeps, GammaV2)
CtVDATAeps = 1/GammaVDataeps
m_VFinal = np.append(m_V1, mVData)
m_VFinal = np.append(m_VFinal, m_V2)


#To obtain the CODEX sensitivity to the Dark Photon's kinetic mixing parameter we need to interpolate 
# the lifetime data we got from CODEX 2203.07316

# To make the code more readable we define the following function:
def eps(ctau,GammaVDataeps):
    return 1/np.sqrt(ctau*GammaVDataeps)

# The interval we want to take into account is:

m_VCODEX = m_VFinal[(m_VFinal > 0.5) & (m_VFinal < 10)]

#FOR BR equal 0.1:

ctauInterp = np.interp(m_VCODEX, [0.5,10], [PointsCODEX1BR[0][0],PointsCODEX1BR[1][0]])

CODEXepsUpperLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 0.5) & (m_VFinal < 10)])

ctauInterp = np.interp(m_VCODEX, [0.5,10], [PointsCODEX1BR[0][1],PointsCODEX1BR[1][1]])

CODEXepsDownLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 0.5) & (m_VFinal < 10)])

#FOR BR equal 0.01:

ctauInterp = np.interp(m_VCODEX, [0.5,10], [PointsCODEX2BR[0][0],PointsCODEX2BR[1][0]])

CODEXepsUpperLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 0.5) & (m_VFinal < 10)])

ctauInterp = np.interp(m_VCODEX, [0.5,10], [PointsCODEX2BR[0][1],PointsCODEX2BR[1][1]])

CODEXepsDownLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 0.5) & (m_VFinal < 10)])

#FOR BR equal 0.001:

ctauInterp = np.interp(m_VCODEX, [0.5,10], [PointsCODEX3BR[0][0],PointsCODEX3BR[1][0]])

CODEXepsUpperLim3 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 0.5) & (m_VFinal < 10)])

ctauInterp = np.interp(m_VCODEX, [0.5,10], [PointsCODEX3BR[0][1],PointsCODEX3BR[1][1]])

CODEXepsDownLim3 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 0.5) & (m_VFinal < 10)])

# %store m_VCODEX

# %store CODEXepsUpperLim1
# %store CODEXepsDownLim1

# %store CODEXepsUpperLim2
# %store CODEXepsDownLim2

# %store CODEXepsUpperLim3
# %store CODEXepsDownLim3

#To obtain the MTHUSLA sensitivity we perform the same procedure but now we have three values for the mass

DATA = np.array(pd.read_excel('1606.06298 MATHUSLA 5 GeV -1 points.xlsx'))
MATHU5GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    MATHU5GeV1[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1606.06298 MATHUSLA 5 GeV -2 points.xlsx'))
MATHU5GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    MATHU5GeV2[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1606.06298 MATHUSLA 5 GeV -3 points.xlsx'))
MATHU5GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    MATHU5GeV3[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1606.06298 MATHUSLA 20 GeV -1 points.xlsx'))
MATHU20GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    MATHU20GeV1[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1606.06298 MATHUSLA 20 GeV -2 points.xlsx'))
MATHU20GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    MATHU20GeV2[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1606.06298 MATHUSLA 20 GeV -3 points.xlsx'))
MATHU20GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    MATHU20GeV3[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1606.06298 MATHUSLA 40 GeV -1 points.xlsx'))
MATHU40GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    MATHU40GeV1[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1606.06298 MATHUSLA 40 GeV -2 points.xlsx'))
MATHU40GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    MATHU40GeV2[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1606.06298 MATHUSLA 40 GeV -3 points.xlsx'))
MATHU40GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    MATHU40GeV3[i] = DATA[i][0]

PointsMATHU1BR = [MATHU5GeV1, MATHU20GeV1, MATHU40GeV1]
PointsMATHU2BR = [MATHU5GeV2, MATHU20GeV2, MATHU40GeV2]
PointsMATHU3BR = [MATHU5GeV3, MATHU20GeV3, MATHU40GeV3]

# The interval we want to take into account is:

m_VMATHU = m_VFinal[(m_VFinal > 5) & (m_VFinal < 40)]


#FOR BR equal 0.1:

ctauInterp = np.interp(m_VMATHU, [5, 20, 40], [PointsMATHU1BR[0][0],PointsMATHU1BR[1][0],PointsMATHU1BR[2][0]])

MATHUepsUpperLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

ctauInterp = np.interp(m_VMATHU, [5, 20, 40], [PointsMATHU1BR[0][1],PointsMATHU1BR[1][1],PointsMATHU1BR[2][1]])

MATHUepsDownLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

#FOR BR equal 0.01:

ctauInterp = np.interp(m_VMATHU, [5, 20, 40], [PointsMATHU2BR[0][0],PointsMATHU2BR[1][0],PointsMATHU2BR[2][0]])

MATHUepsUpperLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

ctauInterp = np.interp(m_VMATHU, [5, 20, 40], [PointsMATHU2BR[0][1],PointsMATHU2BR[1][1],PointsMATHU2BR[2][1]])

MATHUepsDownLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

#FOR BR equal 0.001:

ctauInterp = np.interp(m_VMATHU, [5, 20, 40], [PointsMATHU3BR[0][0],PointsMATHU3BR[1][0],PointsMATHU3BR[2][0]])

MATHUepsUpperLim3 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

ctauInterp = np.interp(m_VMATHU, [5, 20, 40], [PointsMATHU3BR[0][1],PointsMATHU3BR[1][1],PointsMATHU3BR[2][1]])

MATHUepsDownLim3 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

# %store m_VMATHU

# %store MATHUepsUpperLim1
# %store MATHUepsDownLim1

# %store MATHUepsUpperLim2
# %store MATHUepsDownLim2

# %store MATHUepsUpperLim3
# %store MATHUepsDownLim3


#Finally to obtain the ANUBIS sensitivity we do the same as before:

DATA = np.array(pd.read_excel('1909.13022 ANUBIS 5 GeV -1 points.xlsx'))
ANUBIS5GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    ANUBIS5GeV1[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1909.13022 ANUBIS 5 GeV -2 points.xlsx'))
ANUBIS5GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    ANUBIS5GeV2[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1909.13022 ANUBIS 5 GeV -3 points.xlsx'))
ANUBIS5GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    ANUBIS5GeV3[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1909.13022 ANUBIS 10 GeV -1 points.xlsx'))
ANUBIS10GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    ANUBIS10GeV1[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1909.13022 ANUBIS 10 GeV -2 points.xlsx'))
ANUBIS10GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    ANUBIS10GeV2[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1909.13022 ANUBIS 10 GeV -3 points.xlsx'))
ANUBIS10GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    ANUBIS10GeV3[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('1909.13022 ANUBIS 40 GeV -1 points.xlsx'))
ANUBIS40GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    ANUBIS40GeV1[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1909.13022 ANUBIS 40 GeV -2 points.xlsx'))
ANUBIS40GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    ANUBIS40GeV2[i] = DATA[i][0]

DATA = np.array(pd.read_excel('1909.13022 ANUBIS 40 GeV -3 points.xlsx'))
ANUBIS40GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    ANUBIS40GeV3[i] = DATA[i][0]

    
PointsANUBIS1BR = [ANUBIS5GeV1, ANUBIS10GeV1, ANUBIS40GeV1]
PointsANUBIS2BR = [ANUBIS5GeV2, ANUBIS10GeV2, ANUBIS40GeV2]
PointsANUBIS3BR = [ANUBIS5GeV3, ANUBIS10GeV3, ANUBIS40GeV3]

# The interval we want to take into account is:

m_VANUBIS = m_VFinal[(m_VFinal > 5) & (m_VFinal < 40)]


#FOR BR equal 0.1:

ctauInterp = np.interp(m_VANUBIS, [5, 10, 40], [PointsANUBIS1BR[0][0],PointsANUBIS1BR[1][0],PointsANUBIS1BR[2][0]])

ANUBISepsUpperLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

ctauInterp = np.interp(m_VANUBIS, [5, 10, 40], [PointsANUBIS1BR[0][1],PointsANUBIS1BR[1][1],PointsANUBIS1BR[2][1]])

ANUBISepsDownLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

#FOR BR equal 0.01:

ctauInterp = np.interp(m_VANUBIS, [5, 10, 40], [PointsANUBIS2BR[0][0],PointsANUBIS2BR[1][0],PointsANUBIS2BR[2][0]])

ANUBISepsUpperLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

ctauInterp = np.interp(m_VANUBIS, [5, 10, 40], [PointsANUBIS2BR[0][1],PointsANUBIS2BR[1][1],PointsANUBIS2BR[2][1]])

ANUBISepsDownLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

#FOR BR equal 0.001:

ctauInterp = np.interp(m_VANUBIS, [5, 10, 40], [PointsANUBIS3BR[0][0],PointsANUBIS3BR[1][0],PointsANUBIS3BR[2][0]])

ANUBISepsUpperLim3 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

ctauInterp = np.interp(m_VANUBIS, [5, 10, 40], [PointsANUBIS3BR[0][1],PointsANUBIS3BR[1][1],PointsANUBIS3BR[2][1]])

ANUBISepsDownLim3 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 5) & (m_VFinal < 40)])

# %store m_VANUBIS

# %store ANUBISepsUpperLim1
# %store ANUBISepsDownLim1

# %store ANUBISepsUpperLim2
# %store ANUBISepsDownLim2

# %store ANUBISepsUpperLim3
# %store ANUBISepsDownLim3


DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 10 GeV -1.xlsx'))
Ev50ANUBIS10GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS10GeV1[i] = DATA[i][0]

DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 10 GeV -2.xlsx'))
Ev50ANUBIS10GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS10GeV2[i] = DATA[i][0]

DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 10 GeV -3.xlsx'))
Ev50ANUBIS10GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS10GeV3[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 20 GeV -1.xlsx'))
Ev50ANUBIS20GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS20GeV1[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 20 GeV -2.xlsx'))
Ev50ANUBIS20GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS20GeV2[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 20 GeV -3.xlsx'))
Ev50ANUBIS20GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS20GeV3[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 30 GeV -1.xlsx'))
Ev50ANUBIS30GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS30GeV1[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 30 GeV -2.xlsx'))
Ev50ANUBIS30GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS30GeV2[i] = DATA[i][0]

DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 30 GeV -3.xlsx'))
Ev50ANUBIS30GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS30GeV3[i] = DATA[i][0]  
    
DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 40 GeV -1.xlsx'))
Ev50ANUBIS40GeV1 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS40GeV1[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 40 GeV -2.xlsx'))
Ev50ANUBIS40GeV2 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS40GeV2[i] = DATA[i][0]
    
DATA = np.array(pd.read_excel('CERN-THESIS-2022-169 40 GeV -3.xlsx'))
Ev50ANUBIS40GeV3 = np.zeros(len(DATA))
for i in range(len(DATA)):
    Ev50ANUBIS40GeV3[i] = DATA[i][0]

    
PointsEv50ANUBIS1BR = [Ev50ANUBIS10GeV1, Ev50ANUBIS20GeV1, Ev50ANUBIS30GeV1,Ev50ANUBIS40GeV1]
PointsEv50ANUBIS2BR = [Ev50ANUBIS10GeV2, Ev50ANUBIS20GeV2, Ev50ANUBIS30GeV2,Ev50ANUBIS40GeV2]
PointsEv50ANUBIS3BR = [Ev50ANUBIS10GeV3, Ev50ANUBIS20GeV3, Ev50ANUBIS30GeV3,Ev50ANUBIS40GeV3]

# The interval we want to take into account is:

m_VEv50ANUBIS = m_VFinal[(m_VFinal > 10) & (m_VFinal < 40)]


#FOR BR equal 0.1:

ctauInterp = np.interp(m_VEv50ANUBIS, [10, 20, 30, 40], [PointsEv50ANUBIS1BR[0][0],PointsEv50ANUBIS1BR[1][0],PointsEv50ANUBIS1BR[2][0],PointsEv50ANUBIS1BR[3][0]])

Ev50ANUBISepsUpperLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 10) & (m_VFinal < 40)])

ctauInterp = np.interp(m_VEv50ANUBIS, [10, 20, 30, 40], [PointsEv50ANUBIS1BR[0][1],PointsEv50ANUBIS1BR[1][1],PointsEv50ANUBIS1BR[2][1],PointsEv50ANUBIS1BR[3][1]])

Ev50ANUBISepsDownLim1 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 10) & (m_VFinal < 40)])

#FOR BR equal 0.01:

ctauInterp = np.interp(m_VEv50ANUBIS, [10, 20, 30, 40], [PointsEv50ANUBIS2BR[0][0],PointsEv50ANUBIS2BR[1][0],PointsEv50ANUBIS2BR[2][0],PointsEv50ANUBIS2BR[3][0]])

Ev50ANUBISepsUpperLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 10) & (m_VFinal < 40)])

ctauInterp = np.interp(m_VEv50ANUBIS, [10, 20, 30, 40], [PointsEv50ANUBIS2BR[0][1],PointsEv50ANUBIS2BR[1][1],PointsEv50ANUBIS2BR[2][1],PointsEv50ANUBIS2BR[3][1]])

Ev50ANUBISepsDownLim2 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 10) & (m_VFinal < 40)])

#FOR BR equal 0.001:

ctauInterp = np.interp(m_VEv50ANUBIS, [10, 20, 30, 40], [PointsEv50ANUBIS3BR[0][0],PointsEv50ANUBIS3BR[1][0],PointsEv50ANUBIS3BR[2][0],PointsEv50ANUBIS3BR[3][0]])

Ev50ANUBISepsUpperLim3 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 10) & (m_VFinal < 40)])

ctauInterp = np.interp(m_VEv50ANUBIS, [10, 20, 30, 40], [PointsEv50ANUBIS3BR[0][1],PointsEv50ANUBIS3BR[1][1],PointsEv50ANUBIS3BR[2][1],PointsEv50ANUBIS3BR[3][1]])

Ev50ANUBISepsDownLim3 = eps(ctauInterp,GammaVDataeps[(m_VFinal > 10) & (m_VFinal < 40)])

                                                     
# %store m_VEv50ANUBIS

# %store Ev50ANUBISepsUpperLim1
# %store Ev50ANUBISepsDownLim1

# %store Ev50ANUBISepsUpperLim2
# %store Ev50ANUBISepsDownLim2

# %store Ev50ANUBISepsUpperLim3
# %store Ev50ANUBISepsDownLim3
# Out:
#   File "C:\Users\Usuario\AppData\Local\Temp/ipykernel_12872/1826520394.py", line 66
#     m_VCODEX = m_VFinal[m_VFinal > 0.5 && m_VFinal < 10]
#                                         ^
# SyntaxError: invalid syntax
