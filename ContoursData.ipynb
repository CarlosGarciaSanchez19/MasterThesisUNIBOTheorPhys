# %%
# SN 1987A CONTOURS
DATA = np.array(pd.read_excel('1611.03864 SN 1987A contour.xlsx'))
SN1987AContourDATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    SN1987AContourDATA[0][j] = DATA[i][0]
    SN1987AContourDATA[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('1410.0221 SN 1987A ED contour.xlsx'))
SN1987AEDContourDATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    SN1987AEDContourDATA[0][j] = DATA[i][0]
    SN1987AEDContourDATA[1][j] = DATA[i][1]
    j += 1

# E137 CONTOUR
DATA = np.array(pd.read_excel('1209.6083 E137 contour.xlsx'))

E137ContourDATA = np.zeros((2,len(DATA) + 2))
j = 1
for i in range(len(DATA)):
    E137ContourDATA[0][j] = DATA[i][0]
    E137ContourDATA[1][j] = DATA[i][1]
    j += 1
E137ContourDATA[0][0] = 1e-3
E137ContourDATA[1][0] = E137ContourDATA[1][1]
E137ContourDATA[0][-1] = 1e-3
E137ContourDATA[1][-1] = E137ContourDATA[1][-2]

# NuCal CONTOUR
DATA = np.array(pd.read_excel('1908.07525 NuCal contour.xlsx'))
NuCalContourDATA = np.zeros((2,len(DATA) + 2))
j = 1
for i in range(len(DATA)):
    NuCalContourDATA[0][j] = DATA[i][0]
    NuCalContourDATA[1][j] = DATA[i][1]
    j += 1
NuCalContourDATA[0][0] = 1e-3
NuCalContourDATA[1][0] = 1e-6
NuCalContourDATA[0][-1] = 1e-3
NuCalContourDATA[1][-1] = 1e-6

# ATLAS CONTOUR
DATA = np.array(pd.read_excel('2311.18298 Exclusion 10%.xlsx'))

ATLAS10ContourDATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    ATLAS10ContourDATA[0][j] = DATA[i][0]
    ATLAS10ContourDATA[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('2311.18298 Exclusion 5%.xlsx'))

ATLAS5ContourDATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    ATLAS5ContourDATA[0][j] = DATA[i][0]
    ATLAS5ContourDATA[1][j] = DATA[i][1]
    j += 1
    
DATA = np.array(pd.read_excel('2311.18298 Exclusion 1% first.xlsx'))

ATLAS1Contour1DATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    ATLAS1Contour1DATA[0][j] = DATA[i][0]
    ATLAS1Contour1DATA[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('2311.18298 Exclusion 1% second.xlsx'))

ATLAS1Contour2DATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    ATLAS1Contour2DATA[0][j] = DATA[i][0]
    ATLAS1Contour2DATA[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('2311.18298 Exclusion 1% third.xlsx'))

ATLAS1Contour3DATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    ATLAS1Contour3DATA[0][j] = DATA[i][0]
    ATLAS1Contour3DATA[1][j] = DATA[i][1]
    j += 1
    
DATA = np.array(pd.read_excel('2311.18298 Exclusion 0.5% first.xlsx'))

ATLAS05Contour1DATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    ATLAS05Contour1DATA[0][j] = DATA[i][0]
    ATLAS05Contour1DATA[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('2311.18298 Exclusion 0.5% second.xlsx'))

ATLAS05Contour2DATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    ATLAS05Contour2DATA[0][j] = DATA[i][0]
    ATLAS05Contour2DATA[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('2311.18298 Exclusion 0.5% third.xlsx'))

ATLAS05Contour3DATA = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    ATLAS05Contour3DATA[0][j] = DATA[i][0]
    ATLAS05Contour3DATA[1][j] = DATA[i][1]
    j += 1

# 100 TeV lepton jet search reach
DATA = np.array(pd.read_excel('1412.0018 100TeV search reach -1.xlsx'))

Lept1reach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    Lept1reach[0][j] = DATA[i][0]
    Lept1reach[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('1412.0018 100TeV search reach -2.xlsx'))

Lept2reach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    Lept2reach[0][j] = DATA[i][0]
    Lept2reach[1][j] = DATA[i][1]
    j += 1
    
DATA = np.array(pd.read_excel('1412.0018 100TeV search reach -3.xlsx'))

Lept3reach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    Lept3reach[0][j] = DATA[i][0]
    Lept3reach[1][j] = DATA[i][1]
    j += 1
    
DATA = np.array(pd.read_excel('1412.0018 100TeV search reach -4.xlsx'))

Lept4reach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    Lept4reach[0][j] = DATA[i][0]
    Lept4reach[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('1412.0018 100TeV search reach -5.xlsx'))

Lept5reach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    Lept5reach[0][j] = DATA[i][0]
    Lept5reach[1][j] = DATA[i][1]
    j += 1

# 100 TeV lepton jet search reach
DATA = np.array(pd.read_excel('1412.0018 100TeV L1m search reach -1.xlsx'))

L1mLept1reach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    L1mLept1reach[0][j] = DATA[i][0]
    L1mLept1reach[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('1412.0018 100TeV L1m search reach -2.xlsx'))

L1mLept2reach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    L1mLept2reach[0][j] = DATA[i][0]
    L1mLept2reach[1][j] = DATA[i][1]
    j += 1

DATA = np.array(pd.read_excel('1412.0018 100TeV L1m search reach -3.xlsx'))

L1mLept3reach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    L1mLept3reach[0][j] = DATA[i][0]
    L1mLept3reach[1][j] = DATA[i][1]
    j += 1
    
# NA62 reach

DATA = np.array(pd.read_excel('1908.07525 NA62 reach.xlsx'))

NA62reach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    NA62reach[0][j] = DATA[i][0]
    NA62reach[1][j] = DATA[i][1]
    j += 1

# SeaQuest reach
DATA = np.array(pd.read_excel('1908.07525 SeaQuest reach.xlsx'))

LongQuestReach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    LongQuestReach[0][j] = DATA[i][0]
    LongQuestReach[1][j] = DATA[i][1]
    j += 1
    
# SHiP reach

DATA = np.array(pd.read_excel('2011.05115 SHiP reach.xlsx'))

SHiPReach = np.zeros((2,len(DATA)))
j = 0
for i in range(len(DATA)):
    SHiPReach[0][j] = DATA[i][0]
    SHiPReach[1][j] = mt.sqrt(DATA[i][1]) # BECAUSE eps^2 vs m_V IN 2011.05115
    j += 1
    
# %store SN1987AContourDATA

# %store SN1987AEDContourDATA

# %store E137ContourDATA

# %store NuCalContourDATA

# %store ATLAS10ContourDATA

# %store ATLAS5ContourDATA

# %store ATLAS1Contour1DATA

# %store ATLAS1Contour2DATA

# %store ATLAS1Contour3DATA

# %store ATLAS05Contour1DATA

# %store ATLAS05Contour2DATA

# %store ATLAS05Contour3DATA

# %store Lept1reach

# %store Lept2reach

# %store Lept3reach

# %store Lept4reach

# %store Lept5reach

# %store L1mLept1reach

# %store L1mLept2reach

# %store L1mLept3reach

# %store NA62reach

# %store LongQuestReach

# %store SHiPReach
